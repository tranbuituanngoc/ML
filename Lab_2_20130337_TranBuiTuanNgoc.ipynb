# %% [markdown]
# <a href="https://colab.research.google.com/github/tranbuituanngoc/ML/blob/main/Lab_2_20130337_TranBuiTuanNgoc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab #2
# This lab is the first step to get farmilliar with some common Machine Learning libraries, named ***Pandas*** and ***Matlotlib***.
#
# *   **Deadline: 23:59, 27/02/2023**

# %% [markdown]
# #0. Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/ML'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/ML

# %% [markdown]
# #1. Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #2. Load dataset
#
# *   Load dataset (named ***shopping-data.csv***) using ***read_csv*** from pandas
# *   Then, display 10 last examples

# %%
df=pd.read_csv("shopping-data .csv")
df.tail(10)
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# #3. Show statistics of the given dataset

# %%
df.describe
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# #4. Sort dataset by ***Age***

# %%
df.sort_values(by="Age")
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# #5. Group dataset by ***Gender*** and ***Age***

# %%
df.groupby(['Genre','Age']).groups
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# #6. Use scatter plot to represent the relationship between ***Age*** and ***Annual Income***
# Rememer adding titles, xlabel, ylabel, ... to the plot

# %%
age= df['Age']
annual = df['Annual Income (k$)']
plt.scatter(age,annual)
plt.xlabel('Age')
plt.ylabel('Annual Income (k$)')
plt.title("My scatter plot!")
plt.show()

# %% [markdown]
# #7. Use histogram plot to represent the distribution of ***Age***

# %%
age= df['Age']
range = (0, 100) 
bins = 10 
plt.hist(age,bins, range, histtype='bar',rwidth=0.8)
plt.title('My histogram plot')
plt.show()

# %% [markdown]
# #8. Finally,
# Save a copy in your Github. Remember renaming the notebook.
